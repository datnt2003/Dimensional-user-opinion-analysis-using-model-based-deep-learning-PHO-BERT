# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/datnguyen/Documents/hoc_truong/project/NLP/use main_data/new-v4/data.tsv',sep='\t')

# %%
df.isna().sum()
# Out:
# comment        0
# rating_star    0
# khia_canh      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 177

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (285186, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285186 entries, 0 to 285362
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   comment      285186 non-null  object
#  1   rating_star  285186 non-null  object
#  2   khia_canh    285186 non-null  object
# dtypes: object(3)
# memory usage: 8.7+ MB

# %%
df.head()
# Out:
#                                              comment rating_star  \
# 0  mô tả sai 60 cửa hàng giao bao nhiêu bẻ 50 nhắ...    negative
# 1  sản phẩm cửa hàng hài sản phẩm hàng hơi lâu4 ủ...    negative
# 2  giao hàng cửa hàng thèm phục vụ kém nhắn đợi t...    negative
# 3  chất sản phẩm tệ hại y cửa hàng hàng khuyên cử...    negative
# 4  sản phẩm giao cửa hàng phục vụ nhiệt tình 2 sả...    negative
#
#                                            khia_canh
# 0  Chất lượng sản phẩm, Dịch vụ khách hàng, Giao ...
# 1                                 Dịch vụ khách hàng
# 2  Chất lượng sản phẩm, Dịch vụ khách hàng, Giao ...
# 3  Chất lượng sản phẩm, Dịch vụ khách hàng, Giao ...
# 4                      Dịch vụ khách hàng, Giao hàng

# %%
df['khia_canh'].unique().tolist()
# Out:
# ['Chất lượng sản phẩm, Dịch vụ khách hàng, Giao hàng',
#  'Dịch vụ khách hàng',
#  'Chất lượng sản phẩm, Dịch vụ khách hàng, Giao hàng, Đóng gói sản phẩm',
#  'Dịch vụ khách hàng, Giao hàng',
#  'Chất lượng sản phẩm, Dịch vụ khách hàng',
#  'Chất lượng sản phẩm',
#  'Chất lượng sản phẩm, Dịch vụ khách hàng, Giá cả',
#  'Giao hàng',
#  'Dịch vụ khách hàng, Giá cả, Giao hàng',
#  'Chất lượng sản phẩm, Giao hàng',
#  'Chất lượng sản phẩm, Giá cả, Giao hàng, Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Dịch vụ khách hàng, Giá cả, Giao hàng',
#  'Chất lượng sản phẩm, Giá cả, Giao hàng',
#  'Dịch vụ khách hàng, Giá cả',
#  'Giao hàng, Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Giá cả',
#  'Giá cả, Giao hàng',
#  'Giá cả',
#  'Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Dịch vụ khách hàng, Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Giá cả, Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Giao hàng, Đóng gói sản phẩm',
#  'Chất lượng sản phẩm, Đóng gói sản phẩm',
# ...

# %%
df['rating_star'].unique().tolist()
# Out:
# ['negative', 'neutral', 'positive']

# %%
df.shape
# Out:
# (285186, 3)

# %%
sns.countplot(x=df['rating_star'],data=df)
plt.show()

# %%
sns.countplot(x=df['khia_canh'],data=df)
# Out:
# <Axes: xlabel='khia_canh', ylabel='count'>
